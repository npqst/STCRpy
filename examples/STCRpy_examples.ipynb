# %%
import STCRpy
# Out:
# /home/quast/miniconda3/envs/tcrpy/lib/python3.12/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
example_pdb_file = './8gvb.cif'

# %%
# load a TCR structure to a TCR object
from STCRpy import load_TCRs

tcr_8gvb = load_TCRs(example_pdb_file)[0]
# Out:
# Header could not be parsed

# %%
tcr_8gvb
# Out:
# <TCR BA beta=B; alpha=A>

# %%
tcr_8gvb.save()
tcr_8gvb.save(tcr_only=True)

# %%
tcr_8gvb.calculate_docking_geometry()
# Out:
# {'tcr_com': [-0.34983140230178833, -1.750739336013794, 27.47578239440918],
#  'mhc_com': [-0.11810101568698883, 0.28618529438972473, -0.5421134233474731],
#  'tcr_VA_com': [11.094366073608398, -3.4061343669891357, 28.801589965820312],
#  'tcr_VB_com': [-11.06576156616211, -0.20068766176700592, 26.234357833862305],
#  'scanning_angle': 81.76929372060653,
#  'pitch_angle': 6.540735717866954,
#  'polarity': 0}

# %%
tcr_8gvb.score_docking_geometry()
# Out:
# -22.092821029232

# %%
peptide_interactions = tcr_8gvb.profile_peptide_interactions()
peptide_interactions
# Out:
#            type                                       protein_atom  \
# 0    saltbridge                      [((0.387, 14.448, 9.276), 7)]
# 1    saltbridge  [((-2.161, -10.652, 14.118), 8), ((-1.589, -10...
# 2    saltbridge  [((-2.548, -8.057, 5.084), 8), ((-1.57, -9.144...
# 3         hbond                     [((-0.148, -8.505, 0.973), 8)]
# 4         hbond                     [((0.413, -12.102, 3.292), 8)]
# 5         hbond                      [((-0.785, -6.61, 7.569), 7)]
# 6         hbond                        [((5.866, 1.71, 5.595), 7)]
# 7         hbond                       [((-3.088, 3.107, 2.94), 7)]
# 8         hbond                     [((-2.133, 11.415, 2.999), 7)]
# 9         hbond                       [((0.71, 19.141, 4.964), 8)]
# 10        hbond                     [((0.128, 10.228, 10.805), 8)]
# 11        hbond                     [((-0.148, -8.505, 0.973), 8)]
# 12        hbond                     [((-2.548, -8.057, 5.084), 8)]
# 13        hbond                      [((-0.785, -6.61, 7.569), 7)]
# 14      pistack  [((1.68, 7.991, -1.83), 6), ((0.292, 8.003, -1...
# 15  hydrophobic                     [((-3.418, -3.238, 8.036), 6)]
# 16  hydrophobic                       [((-4.92, 1.709, 3.969), 6)]
# 17  hydrophobic                    [((-2.989, 10.679, -3.241), 6)]
# 18  hydrophobic                      [((0.292, 8.003, -1.805), 6)]
# 19  hydrophobic                     [((-0.961, -5.315, -0.59), 6)]
# 20  hydrophobic                       [((3.074, 0.282, 1.709), 6)]
# 21  hydrophobic                     [((2.788, 13.331, -2.535), 6)]
# 22  hydrophobic                      [((2.643, 14.188, -1.46), 6)]
# 23  hydrophobic                      [((3.738, 13.813, 2.683), 6)]
# 24  hydrophobic                       [((7.281, 6.867, 6.394), 6)]
# 25  hydrophobic                       [((7.367, 2.071, 9.219), 6)]
# 26  hydrophobic                      [((5.602, -3.898, 2.977), 6)]
#
#    protein_chain protein_residue  protein_number  \
# 0              C             LYS             145
# 1              C             GLU              61
# 2              C             GLU              62
# 3              C             TYR               6
# 4              C             TYR             170
# 5              C             LYS              65
# 6              C             GLN             155
# 7              C             HIS              69
# 8              C             ASN              76
# 9              C             TYR              83
# 10             B             ASP              96
# 11             C             TYR               6
# 12             C             GLU              62
# 13             C             LYS              65
# 14             C             TYR             115
# 15             C             LYS              65
# 16             C             HIS              69
# 17             C             LEU              94
# 18             C             TYR             115
# 19             C             TYR               6
# 20             C             PHE              98
# 21             C             TYR             122
# 22             C             TYR             122
# 23             C             THR             142
# 24             C             VAL             151
# 25             C             GLN             154
# 26             C             TYR             158
#
#                                           ligand_atom  distance       angle  \
# 0   [((-0.345, 14.859, 6.949), 8), ((0.52, 16.092,...  3.248376         NaN
# 1   [((1.399, -11.29, 8.235), 7), ((0.505, -9.245,...  4.810732         NaN
# 2   [((1.399, -11.29, 8.235), 7), ((0.505, -9.245,...  4.392759         NaN
# 3                       [((1.853, -9.447, 3.288), 7)]  3.201654  127.511553
# 4                       [((1.853, -9.447, 3.288), 7)]  3.020371  152.243008
# 5                       [((0.505, -9.245, 8.791), 7)]  3.178146  127.362929
# 6                        [((2.065, 1.428, 5.601), 8)]  3.811451  112.389240
# 7                       [((-2.078, 3.214, 5.904), 8)]  3.133184  156.306821
# 8                        [((1.052, 11.03, 1.657), 7)]  3.477559  149.802436
# 9                        [((0.52, 16.092, 5.469), 8)]  3.096373  125.059664
# 10                       [((-0.267, 9.34, 7.005), 7)]  3.922317  162.895734
# 11                      [((1.853, -9.447, 3.288), 7)]  3.201654  153.122687
# 12                      [((-0.31, -6.794, 4.372), 7)]  2.666600  160.202716
# 13                      [((0.505, -9.245, 8.791), 7)]  3.178146  105.094921
# 14  [((0.384, 12.991, 2.528), 6), ((0.98, 11.792, ...  5.359264   75.688653
# 15                       [((-2.676, -2.6, 4.194), 6)]  3.964665         NaN
# 16                     [((-3.056, -1.462, 3.507), 6)]  3.707180         NaN
# 17                     [((-0.27, 12.288, -1.542), 6)]  3.587261         NaN
# 18                     [((0.333, 11.378, -0.718), 6)]  3.545966         NaN
# 19                     [((-2.605, -3.821, 2.149), 6)]  3.526598         NaN
# 20                      [((2.341, -2.692, 2.951), 6)]  3.305228         NaN
# 21                     [((-0.27, 12.288, -1.542), 6)]  3.380128         NaN
# 22                    [((-0.711, 13.529, -1.064), 6)]  3.440990         NaN
# 23                      [((0.384, 12.991, 2.528), 6)]  3.456736         NaN
# 24                       [((4.282, 6.024, 7.949), 6)]  3.481763         NaN
# 25                       [((4.919, 5.064, 8.712), 6)]  3.899718         NaN
# 26                      [((2.341, -2.692, 2.951), 6)]  3.476957         NaN
#
#    plip_id original_numbering ligand_residue  ligand_number domain
# 0     None                146            TRP              8   None
# 1     None                 62            ARG              1   None
# 2     None                 63            ARG              1   None
# 3     None                  7            ARG              1   None
# 4     None                171            ARG              1   None
# 5     None                 66            ARG              1   None
# 6     None                156            LEU              4   None
# 7     None                 70            THR              5   None
# 8     None                 77            TRP              8   None
# 9     None                 84            TRP              8   None
# 10    None                110            GLY              7     VB
# 11    None                  7            ARG              1   None
# 12    None                 63            TYR              2   None
# 13    None                 66            ARG              1   None
# 14    None                116            TRP              8   None
# 15    None                 66            TYR              2   None
# 16    None                 70            TYR              2   None
# 17    None                 95            TRP              8   None
# 18    None                116            TRP              8   None
# 19    None                  7            TYR              2   None
# 20    None                 99            PRO              3   None
# 21    None                123            TRP              8   None
# 22    None                123            TRP              8   None
# 23    None                143            TRP              8   None
# 24    None                152            PHE              6   None
# 25    None                155            PHE              6   None
# 26    None                159            PRO              3   None

# %%
tcr_beta_peptide_interactions = peptide_interactions[peptide_interactions.domain == 'VB']
tcr_beta_peptide_interactions
# Out:
#      type                    protein_atom protein_chain protein_residue  \
# 10  hbond  [((0.128, 10.228, 10.805), 8)]             B             ASP
#
#     protein_number                   ligand_atom  distance       angle  \
# 10              96  [((-0.267, 9.34, 7.005), 7)]  3.922317  162.895734
#
#    plip_id original_numbering ligand_residue  ligand_number domain
# 10    None                110            GLY              7     VB

# %%
tcr_8gvb.visualise_interactions(save_as='8gvb_BA_interactions.pse', antigen_residues_to_highlight=[6, 4])
# Out:
# 'examples/8gvb_BA_interactions.pse'

# %%
tcr_8gvb.get_interaction_heatmap(mutation_index=['4-LEU', '7-GLY'], save_as='8gvb_example_interactions_heatmap.png')

# %%
# pytorch graph conversion

# %%
# bach operations
